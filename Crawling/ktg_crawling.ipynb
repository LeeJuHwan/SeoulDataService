# %%
from ktg import Name

# %%
o = Name()

# %%
params = {'KEY': o.opendata_key,
            'TYPE':'json',
            'SERVICE':'SearchOpenDataServiceList',
            'START_INDEX':1,
            'END_INDEX':5}

# %%
o.set_url(params)
# Out:
# 'http://openAPI.seoul.go.kr:8088/4e465a626d30363134304465454b78/json/SearchOpenDataServiceList/1/5/'

# %%
o.get_APItoDataFrame(params)
# Out:
# [{'DB_NM': '서울시 통계정보',
#   'DT_NM': '도로',
#   'INF_ID': 'OA-1000',
#   'INF_NM': '서울시 보도 현황 (폭원별) 통계',
#   'PAR_INFO_TYPE_ID': '1001',
#   'INFO_TYPE_ID': '2006',
#   'PAR_INFO_TYPE_NM': '도시관리',
#   'INFO_TYPE_NM': '도로',
#   'INF_TAG': '보도면적,보도연장, 폭원',
#   'MNG_ORGAN_NAME': '서울특별시',
#   'MNG_STATION_NAME': '디지털정책관 빅데이터담당관',
#   'MANAGER_NAME': '원은묵',
#   'MANAGER_PHONE': '02-2133-4366',
#   'DATA_REG_DTTM': '2017-12-26',
#   'LINK_DESC': '',
#   'LINK_URL': '',
#   'COPYRIGHT_PERSON_NAME': '서울특별시 안전총괄실 안전총괄관 도로관리과',
#   'COPYRIGHT_PERSON_PHONE': '',
#   'COPYRIGHT_3YN': '',
#   'SOURCE_TYPE': 'DB',
#   'CHNG_LOAD_CYCLE': '정기(매년) * 2010년 생산종료',
#   'INF_CCL': '1110',
#   'INF_CCL_NM': 'BY',
#   'SRV_TYPE': 'SHEET',
#   'INF_EXP': '서울시 통계정보시스템에서 제공하는 보도 현황(폭원별)에 대한 통계정보 입니다.서울시 특별시도상 보행도로 현황을 폭원별로 제공하는 일반ㆍ보고통계\r\n',
#   'SHORT_URL': 'http://data.seoul.go.kr/dataList/datasetView.do?infId=10244&srvType=S&serviceKind=2',
#   'LAST_UPD_DTTM': '2018-04-06'},
#  {'DB_NM': '서울시 통계정보',
# ...

# %%
num =0
key = os.getenv("opendata_key")
res = []
for num in tqdm(range(0, 8)):
    url = f'http://openAPI.seoul.go.kr:8088/{key}/json/SearchCatalogService/{num}000/{num}999/'
    response = requests.get(url).json()
    res += response['SearchCatalogService']['row']
df = pd.DataFrame(res)
df['SHORT_URL'] = df['INF_ID'].apply(lambda x : f"https://data.seoul.go.kr/dataList/{x}/S/1/datasetView.do")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[99], line 4
#       2 key = os.getenv("opendata_key")
#       3 res = []
# ----> 4 for num in tqdm(range(0, 8)):
#       5     url = f'http://openAPI.seoul.go.kr:8088/{key}/json/SearchCatalogService/{num}000/{num}999/'
#       6     response = requests.get(url).json()
#
# NameError: name 'tqdm' is not defined

# %%
def set_url(*args):
    url = 'http://openAPI.seoul.go.kr:8088/'
    for v in args:
        url += f'{v}/'
    return url

# %%
set_url(key)
# Out:
# 'http://openAPI.seoul.go.kr:8088/4e465a626d30363134304465454b78/'

# %%
num =0
key = os.getenv("opendata_key")
res = []
for num in tqdm(range(0, 8)):
    url = f'http://openAPI.seoul.go.kr:8088/{seoul_key}/json/{service_name}/{num_start}/{end_start}/{service_id}/'
    response = requests.get(url).json()
    res += response['SearchCatalogService']['row']
df = pd.DataFrame(res)
df['SHORT_URL'] = df['INF_ID'].apply(lambda x : f"https://data.seoul.go.kr/dataList/{x}/S/1/datasetView.do")

# %%
df.drop_duplicates(inplace=True)

# %%
df.columns
# Out:
# Index(['INF_ID', 'INF_NM', 'CATE_NM', 'DITC_NM', 'MAP_CATE_NM',
#        'MNG_ORGAN_NAME', 'MNG_STATION_NAME', 'LINK_DESC', 'MANAGER_NAME',
#        'MANAGER_PHONE', 'CHNG_LOAD_NM', 'DATA_LT_NM', 'LINK_INFO', 'SRV_TYPE',
#        'SHORT_URL'],
#       dtype='object')

# %%
df['SRV_TYPE'].value_counts()
# Out:
# SRV_TYPE
# Sheet,Api          880
# Api,Sheet           62
# Chart,Sheet,Api     14
# Sheet,Api,File      14
# Api                  9
# File                 7
# Sheet,File,Api       5
# Api,File             2
# Api,Sheet,Link       2
# Sheet,Api,Link       2
# Api,Sheet,File       1
# Sheet,Api,Chart      1
# Name: count, dtype: int64

# %%
df['SRV_TYPE'] = df['INF_ID'].apply(lambda x : f"https://data.seoul.go.kr/dataList/{x}/S/1/datasetView.do")

# %%
df[df['SRV_TYPE'] == 'File']['SHORT_URL']
# Out:
# 193    http://data.seoul.go.kr/dataList/OA-15592/F/1/...
# 614    http://data.seoul.go.kr/dataList/OA-21221/F/1/...
# 621    http://data.seoul.go.kr/dataList/OA-21229/F/1/...
# 633    http://data.seoul.go.kr/dataList/OA-21228/F/1/...
# 763    http://data.seoul.go.kr/dataList/OA-21227/F/1/...
# 794    http://data.seoul.go.kr/dataList/OA-21222/F/1/...
# 848    http://data.seoul.go.kr/dataList/OA-21226/F/1/...
# Name: SHORT_URL, dtype: object

# %%
response['SearchCatalogService'].keys()
# Out:
# dict_keys(['list_total_count', 'RESULT', 'row'])

# %%
df = pd.DataFrame(response['SearchCatalogService']['row'])
# Out:
#        INF_ID                       INF_NM CATE_NM      DITC_NM MAP_CATE_NM
# 0    OA-12615     서울시 강동구 명일2동 주민센터 새소식 정보   공공데이터  자치구 및 자치구산하        일반행정  \
# 1    OA-12621     서울시 강동구 암사2동 주민센터 새소식 정보   공공데이터  자치구 및 자치구산하        일반행정
# 2    OA-12611       서울시 강동구 길동 주민센터 새소식 정보   공공데이터  자치구 및 자치구산하        일반행정
# 3    OA-18805         서울시 성동구 통신판매업 인허가 정보   공공데이터      서울시(본청)       산업/경제
# 4    OA-19284       서울시 성북구 건물위생관리업 인허가 정보   공공데이터      서울시(본청)          환경
# ..        ...                          ...     ...          ...         ...
# 994  OA-17324      서울시 성북구 비디오물소극장업 인허가 정보   공공데이터      서울시(본청)       문화/관광
# 995  OA-16387          서울시 동대문구 안경업 인허가 정보   공공데이터  자치구 및 자치구산하          보건
# 996  OA-17318       서울시 중구 비디오물소극장업 인허가 정보   공공데이터      서울시(본청)       문화/관광
# 997  OA-16040          서울시 비디오물소극장업 인허가 정보   공공데이터      서울시(본청)       문화/관광
# 998  OA-15978  서울시 마포구 중앙도서관 공기질(IoT) 측정정보   공공데이터      서울시(본청)          환경
#
# ...

# %%
import requests

url = 'http://openapi.seoul.go.kr:8088/sample/xml/CardSubwayStatsNew/1/5/20220301'

response = requests.get(url)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n<CardSubwayStatsNew>\n<list_total_count>593</list_total_count>\n<RESULT>\n<CODE>INFO-000</CODE>\n<MESSAGE>\xec\xa0\x95\xec\x83\x81 \xec\xb2\x98\xeb\xa6\xac\xeb\x90\x98\xec\x97\x88\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa4</MESSAGE>\n</RESULT>\n<row>\n<USE_DT>20220301</USE_DT>\n<LINE_NUM>1\xed\x98\xb8\xec\x84\xa0</LINE_NUM>\n<SUB_STA_NM>\xec\x84\x9c\xec\x9a\xb8\xec\x97\xad</SUB_STA_NM>\n<RIDE_PASGR_NUM>20994</RIDE_PASGR_NUM>\n<ALIGHT_PASGR_NUM>19468</ALIGHT_PASGR_NUM>\n<WORK_DT>20220304</WORK_DT>\n</row>\n<row>\n<USE_DT>20220301</USE_DT>\n<LINE_NUM>1\xed\x98\xb8\xec\x84\xa0</LINE_NUM>\n<SUB_STA_NM>\xec\x8b\x9c\xec\xb2\xad</SUB_STA_NM>\n<RIDE_PASGR_NUM>12439</RIDE_PASGR_NUM>\n<ALIGHT_PASGR_NUM>12379</ALIGHT_PASGR_NUM>\n<WORK_DT>20220304</WORK_DT>\n</row>\n<row>\n<USE_DT>20220301</USE_DT>\n<LINE_NUM>1\xed\x98\xb8\xec\x84\xa0</LINE_NUM>\n<SUB_STA_NM>\xec\xa2\x85\xea\xb0\x81</SUB_STA_NM>\n<RIDE_PASGR_NUM>15750</RIDE_PASGR_NUM>\n<ALIGHT_PASGR_NUM>13544</
# ...

# %%
json_response = json.dumps(response.decode('utf-8'))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 json_response = json.dumps(response.decode('utf-8'))
#
# AttributeError: 'Response' object has no attribute 'decode'

# %%
r_dict = json.loads(response.text)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 r_dict = json.loads(response.text)
#
# File ~/miniforge3/envs/seoul/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/miniforge3/envs/seoul/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
# ...

# %%
import json
import urllib.request
from urllib.request import Request, urlopen

# %%
urlhistory = urllib.request.urlopen(url)
readhistory = urlhistory.read()

jsons = json.loads(readhistory)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[21], line 4
#       1 urlhistory = urllib.request.urlopen(url)
#       2 readhistory = urlhistory.read()
# ----> 4 jsons = json.loads(readhistory)
#
# File ~/miniforge3/envs/seoul/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/miniforge3/envs/seoul/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
# ...

# %%
readhistory
# Out:
# b'<?xml version="1.0" encoding="UTF-8"?>\n<SearchCatalogService>\n<list_total_count>7399</list_total_count>\n<RESULT>\n<CODE>INFO-000</CODE>\n<MESSAGE>\xec\xa0\x95\xec\x83\x81 \xec\xb2\x98\xeb\xa6\xac\xeb\x90\x98\xec\x97\x88\xec\x8a\xb5\xeb\x8b\x88\xeb\x8b\xa4</MESSAGE>\n</RESULT>\n<row>\n<INF_ID>OA-17298</INF_ID>\n<INF_NM>\xec\x84\x9c\xec\x9a\xb8\xec\x8b\x9c \xec\xa4\x91\xeb\x9e\x91\xea\xb5\xac \xeb\xb9\x84\xeb\x94\x94\xec\x98\xa4\xeb\xac\xbc\xeb\xb0\xb0\xea\xb8\x89\xec\x97\x85 \xec\x9d\xb8\xed\x97\x88\xea\xb0\x80 \xec\xa0\x95\xeb\xb3\xb4</INF_NM>\n<CATE_NM>\xea\xb3\xb5\xea\xb3\xb5\xeb\x8d\xb0\xec\x9d\xb4\xed\x84\xb0</CATE_NM>\n<DITC_NM>\xec\x84\x9c\xec\x9a\xb8\xec\x8b\x9c(\xeb\xb3\xb8\xec\xb2\xad)</DITC_NM>\n<MAP_CATE_NM>\xeb\xac\xb8\xed\x99\x94/\xea\xb4\x80\xea\xb4\x91</MAP_CATE_NM>\n<MNG_ORGAN_NAME>\xec\xa4\x91\xeb\x9e\x91\xea\xb5\xac</MNG_ORGAN_NAME>\n<MNG_STATION_NAME>\xec\x8a\xa4\xeb\xa7\x88\xed\x8a\xb8\xeb\x8f\x84\xec\x8b\x9c\xec\xa0\x95\xec\xb1\x85\xea\xb4\x80 \xeb\xb9\x85\x
# ...
